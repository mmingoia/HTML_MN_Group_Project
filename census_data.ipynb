# %%
import pandas

# %%
census_df = pandas.read_csv("HTML_MN_Group_Project/Data/Census/2000_Census_Data.csv")
print(census_df)
# Out:
#              State Total Population         Male       Female Under 5 Years  \
# 0          Alabama       4,447,100    2,146,504    2,300,596       295,992
# 1           Alaska         626,932      324,112      302,820        47,591
# 2          Arizona       5,130,632    2,561,057    2,569,575       382,386
# 3         Arkansas       2,673,400    1,304,693    1,368,707       181,585
# 4       California      33,871,648   16,874,892   16,996,756     2,486,981
# 5         Colorado       4,301,261    2,165,983    2,135,278       297,505
# 6      Connecticut       3,405,565    1,649,319    1,756,246       223,344
# 7         Delaware         783,600      380,541      403,059        51,531
# 8          Florida      15,982,378    7,797,715    8,184,663       945,823
# 9          Georgia       8,186,453    4,027,113    4,159,340       595,150
# 10          Hawaii       1,211,537      608,671      602,866        78,163
# ...

# %%
voting_ages = census_df[["18+ Years (All)" , "18+ (Male)" , "18+ (Female)"]]
print(voting_ages)
# Out:
#    18+ Years (All)   18+ (Male) 18+ (Female)
# 0       3,323,678    1,570,851    1,752,827
# 1         436,215      226,111      210,104
# 2       3,763,685    1,859,746    1,903,939
# 3       1,993,031      955,418    1,037,613
# 4      24,621,819   12,130,354   12,491,465
# 5       3,200,466    1,600,273    1,600,193
# 6       2,563,877    1,218,230    1,345,647
# 7         589,013      280,643      308,370
# 8      12,336,038    5,926,729    6,409,309
# 9       6,017,219    2,915,524    3,101,695
# 10        915,770      456,446      459,324
# 11        924,923      458,934      465,989
# 12      9,173,842    4,417,904    4,755,938
# 13      4,506,089    2,174,756    2,331,333
# 14      2,192,686    1,058,805    1,133,881
# 15      1,975,425      962,194    1,013,231
# 16      3,046,951    1,464,021    1,582,930
# 17      3,249,177    1,539,808    1,709,369
# 18        973,685      465,746      507,939
# 19      3,940,314    1,864,136    2,076,178
# ...

# %%
census_df.iloc[:,27:53]
# Out:
#           White Black or African American American Indian and Alaska Native  \
# 0    3,162,808                 1,155,930                            22,430
# 1      434,534                    21,787                            98,043
# 2    3,873,611                   158,873                           255,879
# 3    2,138,598                   418,950                            17,808
# 4   20,170,059                 2,263,882                           333,346
# 5    3,560,005                   165,063                            44,241
# 6    2,780,355                   309,843                             9,639
# 7      584,773                   150,666                             2,731
# 8   12,465,029                 2,335,505                            53,541
# 9    5,327,281                 2,349,542                            21,737
# 10     294,102                    22,003                             3,535
# ...
