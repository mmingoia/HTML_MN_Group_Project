# %%
import pandas as pd

# %%
reasons = pd.read_csv("./../DashboardCreation/nationalreasonsdata.csv")
reasons.head()
# Out:
#    electionyear  nonvotersinthousands  illnessordisability  \
# 0          2000                 18724                0.148
# 1          2004                 16334                0.154
# 2          2016                 18933                0.117
# 3          2012                 19141                0.140
# 4          2008                 15167                0.149
#
#    outoftownawayfromhome  forgot  notinterested  toobusy  \
# 0                  0.102   0.040          0.122    0.209
# 1                  0.090   0.034          0.107    0.199
# 2                  0.079   0.030          0.154    0.143
# 3                  0.086   0.039          0.157    0.189
# 4                  0.088   0.026          0.134    0.175
#
#    transportationproblems  didnotlikecandidatesorcampaignissues  \
# 0                   0.024                                 0.077
# 1                   0.021                                 0.099
# 2                   0.026                                 0.248
# ...

# %%
competitive = pd.read_csv("./../DashboardCreation/compeditivenessdata.csv")
competitive.head()
# Out:
#   yearstate  electionyear stateabbreviation  democratcandidatevotes  \
# 0   2000-AK          2000                AK                  124376
# 1   2000-AL          2000                AL                 1178271
# 2   2000-AR          2000                AR                  778134
# 3   2000-AZ          2000                AZ                 1243190
# 4   2000-CA          2000                CA                17200888
#
#    republicancandidatevotes  othercandidatevotes  totalvotes  percentdemocrat  \
# 0                    358260                77317      559953             0.22
# 1                   1790402               136593     3105266             0.38
# 2                    750086                26326     1554546             0.50
# 3                   2744563               406995     4394748             0.28
# 4                  12900577              1925670    32027135             0.54
#
#    percentrepublican  percentother  firstplace  secondplace  competivness
# ...
